# %% [markdown]
# # **HW 3: Used Car Price Prediction with Linear Regression & KNN**
#
# ## **Objective**
# In this assignment, you will work with the "used car" dataset, applying data cleansing, linear regression, and K-Nearest Neighbors (KNN) regression to predict car prices.
#
# ---
#
# ## **Part 1: Data Preprocessing**
# ### **Tasks:**
# 1. **Fix Data Issues**
#    - Correct the typo: rename the column `"milage"` to `"mileage"`.
#
# 2. **Convert Numerical Variables**
#    - Ensure `"mileage"` and `"model_year"` are treated as numerical variables.
#
# 3. **Encode Categorical Variables**
#    - Apply one-hot encoding to the categorical columns:
#      - `"fuel_type"`
#      - `"clean_title"`
#      - `"engine"`
#      - `"transmission"`
#      - `"ext_col"` (exterior color)
#      - `"int_col"` (interior color)
#
# 4. **Remove Anomalies**
#    - Identify and handle any anomalies or outliers in the dataset.
#
# ---
#
# ## **Part 2: Linear Regression Model**
# ### **Tasks:**
# 1. **Feature Selection**
#    - Use `"mileage"`, `"model_year"`, and all one-hot encoded features as independent variables.
#    - The dependent variable is `"price"`.
#
# 2. **Train-Test Split**
#    - Split the dataset into **80% training** and **20% testing**.
#
# 3. **Train Linear Regression Model**
#    - Fit a linear regression model using the training data.
#
# 4. **Evaluate the Model**
#    - Calculate and report the **Root Mean Squared Error (RMSE)** on the test data.
#
# 5. **Visualization**
#    - Plot a **scatter chart** with:
#      - **X-axis:** `"mileage"`
#      - **Y-axis:** `"price"`
#      - Differentiate **actual vs. predicted** prices.
#
# ---
#
# ## **Part 3: K-Nearest Neighbors (KNN) Regression**
# ### **Tasks:**
# 1. **Train KNN Model**
#    - Use the same independent variables as in Part 2.
#    - Choose an appropriate value for **k** (e.g., 3, 5, or 7).
#
# 2. **Evaluate the Model**
#    - Calculate and report the **RMSE** on the test data.
#
# 3. **Visualization**
#    - Plot a **scatter chart** with:
#      - **X-axis:** `"mileage"`
#      - **Y-axis:** `"price"`
#      - Differentiate **actual vs. predicted** prices.
#
# ---
